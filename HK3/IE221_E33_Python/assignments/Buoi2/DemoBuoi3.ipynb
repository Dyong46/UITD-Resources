# %%
tuoi = 26
tinh_trang_sk = True
diem_thi = 89.5

if tuoi >= 18 and tinh_trang_sk and diem_thi >= 80:
    print("Du dieu kien cap")
else:
    print("Khong du dieu kien cap")

print("another ...")
# Out:
# Du dieu kien cap
# another ...

# %% [markdown]
# ### if 2 nhanh

# %%
if tuoi >= 18:
    if tinh_trang_sk:
        if diem_thi >= 80:
            print("Du dieu kien cap")
        else:
            print("Khong du dieu kien cap")
    else:
        print("Khong du dieu kien cap")
else:
    print("Khong du dieu kien cap")
# Out:
# Du dieu kien cap

# %%
nguoi = input("Nguoi ra:")

import random as r

may = r.choice(['keo', 'bua', 'bao'])

print('May ra:', may)

print()
