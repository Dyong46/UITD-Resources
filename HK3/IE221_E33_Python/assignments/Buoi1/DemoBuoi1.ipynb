# %% [markdown]
# # Demo Buổi 01

# %% [markdown]
# ## 1. Các kiểu dữ liệu trong Python

# %%
x = 10
y = 3.14

# %%
print("x =", x, "y =", y)
# Out:
# x = 10 y = 3.14

# %%
del x

# %%
print("x + y", x + y)
# Out:
# x + y 13.14

# %%
n = input("Input n = ")

# %%
print("n =", n)
# Out:
# n = 11

# %%
x
# Out:
# 10

# %%
y
# Out:
# 3.14

# %%
n
# Out:
# '11'

# %%
type(x)
# Out:
# int
