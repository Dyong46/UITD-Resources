# %% [markdown]
# # Data types in Python language

# %% [markdown]
# ## 1. Number type - int - float - int() - float()

# %%
x = 10
y = 5.6

# %%
salary_base = 10000000
salary_base = 10_000_000

# %%
salary_per_month = 10e6

# %%
int(10.6)
# Out:
# 10

# %%
float(20)
# Out:
# 20.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
10%3.5
# Out:
# 3.0

# %%
10/3.5
# Out:
# 2.857142857142857

# %%
10//3.5
# Out:
# 2.0

# %%
pow(2, 3)  # 2^3
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
import math

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
import math as m

# %%
m.sqrt(100)
# Out:
# 10.0

# %% [markdown]
# ## 2. String type - str - str()

# %%
first_last_name = "Hello World"

# %%
ht = 'Hello World'

# %%
first_last_name
# Out:
# 'Hello World'

# %%
first_last_name[-1]
# Out:
# 'd'

# %%
first_last_name.split()
# Out:
# ['Hello', 'World']

# %%
e = 'info@citd.edu.vn'

# %%
e.split("@")
# Out:
# ['info', 'citd.edu.vn']

# %%
e.split('.')
# Out:
# ['info@citd', 'edu', 'vn']

# %% [markdown]
# ## 3. List type - list - list()

# %%
ds = [
    "Nguyen Van A",
    6.8,
    80,
]

# %%
ds2 = ['Nguyen Van A', 6.8, 80]

# %%
ds
# Out:
# ['Nguyen Van A', 6.8, 80]

# %%
type(ds)
# Out:
# list

# %%
import numpy

# %%
d = [1, 5, 6, 'ac', 9, 5, 8]

# %%
d.append(5)

# %%
d.append([1, 6, 3])

# %%
d
# Out:
# [1, 5, 6, 'ac', 9, 5, 8, 5, [1, 6, 3]]

# %%
d.pop(1)
# Out:
# 5

# %%
d
# Out:
# [1, 6, 'ac', 9, 5, 8, 5, [1, 6, 3]]

# %%
d = [1, 5, 6, 'ac', 9, 5, 8]

# %%
d[3] = 9

# %%
d
# Out:
# [1, 5, 6, 9, 9, 5, 8]

# %% [markdown]
# ## 4. Tuple type - tuple - tuple()

# %%
()
# Out:
# ()

# %%
('Nguyen Van A', 6.8, 80)
# Out:
# ('Nguyen Van A', 6.8, 80)

# %%
# Number type
# String type                   index + -           get/set
# List type                     index + -           get/set
# Tuple type                    index + -           get/_
# Dic type                      index
# Set

# %% [markdown]
# ## 5. Dictionary

# %%
dict_name = {
    520189: "MIT",
    "IT": "Information Technology",
    "SE": "Software Engineering",
    "CS": "Computer Science"
}

# %%
print(dict_name[520189])
print(dict_name["IT"])
print(dict_name)
# Out:
# MIT
# Information Technology
# {520189: 'MIT', 'IT': 'Information Technology', 'SE': 'Software Engineering', 'CS': 'Computer Science'}

# %%
dict_name.get("SE")
# Out:
# 'Software Engineering'

# %%
print(dict_name["ac"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(dict_name["ac"])
#
# KeyError: 'ac'

# %%
dict_name.get("ac", "Khong co")
# Out:
# 'Khong co'

# %% [markdown]
# ## 6. Kieu tap hop - set - set()

# %%
th = {
    "Nguyen Van A",
    6.8,
    80
}

# %%
th
# Out:
# {6.8, 80, 'Nguyen Van A'}

# %%
th = {7.7, 8.8, 9.9, 8.8}

# %%
th
# Out:
# {7.7, 8.8, 9.9}

# %% [markdown]
# ## 7. Bool type - bool()

# %%
True
False
# Out:
# False

# %%
tinh_trang_tn = False

# %%
tinh_trang_tn = True

# %%
# Tuong ung voi False
# str: "" -
# list
# tuple
# dict
# set

# %% [markdown]
# ## 7. None value

# %%
None

# %%
# II. Toan tu

# %%
pow(2, 3)
# Out:
# 8

# %%
2 ** 3
# Out:
# 8

# %%
x = 10
x = x + 1
x += 2

# %%
x
# Out:
# 13

# %%
x += 1
x
# Out:
# 14

# %%
# &&        and
# //        or

# %%
True and True and True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
s = "hom nay troi mua"

# %%
"mua" in s
# Out:
# True

# %%
"Mua" in s
# Out:
# False

# %%
nv = {
    "ma_nv": "Nguyen Van A",
    "diem_tb": 6.8,
    "diem_rl": 80
}

# %%
'diem_tb' in nv
# Out:
# True
