# %%
def y(x):
    return 2*x + 1

# %%
y(2)
# Out:
# 5

# %%
(lambda x: 2*x + 1)(2)
# Out:
# 5

# %%
def y(x):
    return 2*x + 1

# %%
ds = [9, 6, 1, -2, 3, -4, 5]

[(lambda i: i+1)(i) for i in ds]
# Out:
# [10, 7, 2, -1, 4, -3, 6]

# %%
sorted(ds, key=lambda x: abs(x))
# Out:
# [1, -2, 3, -4, 5, 6, 9]

# %%
ds = [nv1, nv2, nv3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds = [nv1, nv2, nv3]
#
# NameError: name 'nv1' is not defined

# %%
ds = [9, 6, 1, -2, 3, -4, 5]

f = filter(lambda x: x > 0, ds)

list(f)
# Out:
# [9, 6, 1, 3, 5]

# %%
ds = [9, 6, 1, -2, 3, -4, 5]

m = map(lambda x: x*2, ds)

list(m)
# Out:
# [18, 12, 2, -4, 6, -8, 10]
